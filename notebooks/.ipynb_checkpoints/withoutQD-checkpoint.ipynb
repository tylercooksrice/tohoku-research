# %%
#libraries
import h5py
import numpy as np
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams, PointStruct
import random
import time
import matplotlib.pyplot as plt

# %%
client = QdrantClient(
    host="qdrant",
    port=6333
)

client.get_collections()
# Out:
# CollectionsResponse(collections=[CollectionDescription(name='collection1'), CollectionDescription(name='test_collection')])

# %%
def create_collection(collection_name):
    client.create_collection(
    collection_name=collection_name,
    vectors_config=VectorParams(
        size=128,
        distance=Distance.EUCLID
        )
    )
    return None

def insert_data(collection_name):
    # opening file
    with h5py.File('../datasets/sift-128-euclidean.hdf5', 'r') as h5f:
        for keys in list(h5f["train"]):
            client.upsert(
                collection_name=collection_name,
                points=[PointStruct(id=i,vector=v.tolist())
            for i, v, in enumerate(vectors)
                   ])
    return None

# %%
name = "collection1"

create_collection(name);
print("Collection created")
# Out:
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[11], line 3
#       1 name = "collection1"
# ----> 3 create_collection(name);
#       4 print("Collection created")
#
# Cell In[10], line 2, in create_collection(collection_name)
#       1 def create_collection(collection_name):
# ----> 2     client.create_collection(
#       3     collection_name=collection_name,
#       4     vectors_config=VectorParams(
#       5         size=128,
#       6         distance=Distance.EUCLID
#       7         )
#       8     )
#       9     return None
#
# File /opt/conda/lib/python3.11/site-packages/qdrant_client/qdrant_client.py:1750, in QdrantClient.create_collection(self, collection_name, vectors_config, sparse_vectors_config, shard_number, sharding_method, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, timeout, strict_mode_config, metadata, **kwargs)
#    1700 """Create empty collection with given parameters
#    1701
#    1702 Args:
#    (...)
#    1746     Operation result
#    1747 """
#    1748 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# -> 1750 return self._client.create_collection(
#    1751     collection_name=collection_name,
#    1752     vectors_config=vectors_config,
#    1753     shard_number=shard_number,
#    1754     sharding_method=sharding_method,
#    1755     replication_factor=replication_factor,
#    1756     write_consistency_factor=write_consistency_factor,
#    1757     on_disk_payload=on_disk_payload,
#    1758     hnsw_config=hnsw_config,
#    1759     optimizers_config=optimizers_config,
#    1760     wal_config=wal_config,
#    1761     quantization_config=quantization_config,
#    1762     timeout=timeout,
#    1763     sparse_vectors_config=sparse_vectors_config,
#    1764     strict_mode_config=strict_mode_config,
#    1765     metadata=metadata,
#    1766     **kwargs,
#    1767 )
#
# File /opt/conda/lib/python3.11/site-packages/qdrant_client/qdrant_remote.py:2108, in QdrantRemote.create_collection(self, collection_name, vectors_config, shard_number, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, timeout, sparse_vectors_config, sharding_method, strict_mode_config, metadata, **kwargs)
#    2090     quantization_config = GrpcToRest.convert_quantization_config(quantization_config)
#    2092 create_collection_request = models.CreateCollection(
#    2093     vectors=vectors_config,
#    2094     shard_number=shard_number,
#    (...)
#    2105     metadata=metadata,
#    2106 )
# -> 2108 result: bool | None = self.http.collections_api.create_collection(
#    2109     collection_name=collection_name,
#    2110     create_collection=create_collection_request,
#    2111     timeout=timeout,
#    2112 ).result
#    2114 assert result is not None, "Create collection returned None"
#    2115 return result
#
# File /opt/conda/lib/python3.11/site-packages/qdrant_client/http/api/collections_api.py:451, in SyncCollectionsApi.create_collection(self, collection_name, timeout, create_collection)
#     442 def create_collection(
#     443     self,
#     444     collection_name: str,
#     445     timeout: int = None,
#     446     create_collection: m.CreateCollection = None,
#     447 ) -> m.InlineResponse2001:
#     448     """
#     449     Create new collection with given parameters
#     450     """
# --> 451     return self._build_for_create_collection(
#     452         collection_name=collection_name,
#     453         timeout=timeout,
#     454         create_collection=create_collection,
#     455     )
#
# File /opt/conda/lib/python3.11/site-packages/qdrant_client/http/api/collections_api.py:96, in _CollectionsApi._build_for_create_collection(self, collection_name, timeout, create_collection)
#      94 if "Content-Type" not in headers:
#      95     headers["Content-Type"] = "application/json"
# ---> 96 return self.api_client.request(
#      97     type_=m.InlineResponse2001,
#      98     method="PUT",
#      99     url="/collections/{collection_name}",
#     100     headers=headers if headers else None,
#     101     path_params=path_params,
#     102     params=query_params,
#     103     content=body,
#     104 )
#
# File /opt/conda/lib/python3.11/site-packages/qdrant_client/http/api_client.py:95, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      93     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      94 request = self._client.build_request(method, url, **kwargs)
# ---> 95 return self.send(request, type_)
#
# File /opt/conda/lib/python3.11/site-packages/qdrant_client/http/api_client.py:130, in ApiClient.send(self, request, type_)
#     128     except ValidationError as e:
#     129         raise ResponseHandlingException(e)
# --> 130 raise UnexpectedResponse.for_response(response)
#
# UnexpectedResponse: Unexpected Response: 409 (Conflict)
# Raw response content:
# b'{"status":{"error":"Wrong input: Collection `collection1` already exists!"},"time":0.000082248}'

# %%
# opening file
BATCH_MAX_SIZE = 1000

with h5py.File('../datasets/sift-128-euclidean.hdf5', 'r') as h5f:
    #for keys in list(h5f["train"]):
     #   print(keys)
    #print(h5f["train"].shape)
    #for key in h5f.keys():
        #obj = h5f[key]
        #print (key, obj[0])
    #print(h5f["train"][1])
    for batch_level in range(0, h5f["train"].shape[0], BATCH_MAX_SIZE):
        batch = h5f["train"][batch_level:batch_level + BATCH_MAX_SIZE]
        points=[PointStruct(id=batch_level+j, vector=vector.tolist())
                           for j, vector in enumerate(batch)]
        
        client.upsert(
            collection_name="collection1",
            points=points)
    print("added successfully")
    #client.upsert(
        #collection_name="collection1",
        #points=[PointStruct(id=i,vector=v.tolist())
    #for i, v, in enumerate(h5f["train"])
           #])
    
# try to insert 100 items at one time
# Out:
# added successfully

# %%
#testing data
with h5py.File('../datasets/sift-128-euclidean.hdf5', 'r') as h5f:
    query_vector = h5f["test"][0]

    results = client.query_points(
        collection_name="collection1",
        query=query_vector.tolist(),
        limit=10,
    )

print(results)
# Out:
# points=[ScoredPoint(id=932085, version=1934, score=232.87122, payload={}, vector=None, shard_key=None, order_value=None), ScoredPoint(id=934876, version=1936, score=234.71472, payload={}, vector=None, shard_key=None, order_value=None), ScoredPoint(id=561813, version=1563, score=243.98976, payload={}, vector=None, shard_key=None, order_value=None), ScoredPoint(id=708177, version=1710, score=255.46037, payload={}, vector=None, shard_key=None, order_value=None), ScoredPoint(id=706771, version=1708, score=256.31427, payload={}, vector=None, shard_key=None, order_value=None), ScoredPoint(id=695756, version=1697, score=258.86288, payload={}, vector=None, shard_key=None, order_value=None), ScoredPoint(id=435345, version=1437, score=261.24127, payload={}, vector=None, shard_key=None, order_value=None), ScoredPoint(id=701258, version=1703, score=264.28015, payload={}, vector=None, shard_key=None, order_value=None), ScoredPoint(id=455537, version=1457, score=267.2845, payload={}, vector=None, shard_key=None, order_value=None), ScoredPoint(id=872728, version=1874, score=268.06903, payload={}, vector=None, shard_key=None, order_value=None)]

# %%
with h5py.File('../datasets/sift-128-euclidean.hdf5', 'r') as h5f:
    print(h5f["neighbors"][0][:10])
# Out:
# [932085 934876 561813 708177 706771 695756 435345 701258 455537 872728]

# %%
#Pipeline test
recalls = []
latency = []
test_data = []
counter = 0
recall_total = 0
recall_answer = 0
with h5py.File('../datasets/sift-128-euclidean.hdf5', 'r') as h5f:
    for j in range(10000):
        query_vector = h5f["test"][j]
        results = (client.query_points(
            collection_name="collection1",
            query=query_vector.tolist(),
            limit=10,
        ))
        #match formats
        for i in h5f["neighbors"][j][:10]:
            recalls.append(i)
        for i in results.points:
            test_data.append(i.id)
    
    amount = list(set(test_data) - set(recalls))
    
    recall = (len(test_data) - len(amount))/ ( len(recalls))
    counter += 1
    recall_total += recall
    recall_answer = (recall_total / counter) * 100
    recalls = []
    test_data = []

print (f"Recall@10: {recall_answer}%")
# Out:
# Recall@10: 98.428%

# %%
#Latency
recalls = []
latency = []
test_data = []
counter = 0
recall_total = 0
recall_answer = 0
with h5py.File('../datasets/sift-128-euclidean.hdf5', 'r') as h5f:
    for j in range(10000):
        query_vector = h5f["test"][j]
        start = time.perf_counter()
        results = (client.query_points(
            collection_name="collection1",
            query=query_vector.tolist(),
            limit=10,
        ))
        end = time.perf_counter()
        #caluclate latency
        latency.append((end - start) * 1000)
        #match formats
        for i in h5f["neighbors"][j][:10]:
            recalls.append(i)
        for i in results.points:
            test_data.append(i.id)
    
    amount = list(set(test_data) - set(recalls))
    
    recall = (len(test_data) - len(amount))/ ( len(recalls))
    counter += 1
    recall_total += recall
    recall_answer = (recall_total / counter) * 100
    recalls = []
    test_data = []

print (f"Recall@10: {recall_answer}%")
print(f"Average latency: {np.mean(latency):.3f} ms")
print(f"Median latency: {np.median(latency):.3f} ms")
print(f"Minimum latency: {np.min(latency):.3f} ms")
print(f"Maximum latency: {np.max(latency):.3f} ms")
print(f"Standard deviation: {np.std(latency):.3f} ms")
# Out:
# Recall@10: 98.4%
# Average latency: 1.799 ms
# Median latency: 1.610 ms
# Minimum latency: 1.286 ms
# Maximum latency: 167.214 ms
# Standard deviation: 1.727 ms

# %%
#display data
plt.figure(figsize=(10, 5))
plt.plot(latency, linewidth=0.8)
plt.title("Query Latency")
plt.xlabel("Query Number")
plt.ylabel("Latency (ms)")
plt.grid(True)
plt.tight_layout()
plt.show()
